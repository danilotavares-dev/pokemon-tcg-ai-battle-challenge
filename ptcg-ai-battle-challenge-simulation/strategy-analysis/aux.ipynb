# %%
import pandas as pd

# %%
df = pd.read_csv('../utils/Card_Data.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2022 entries, 0 to 2021
# Data columns (total 17 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Card ID                                    2022 non-null   int64
#  1   Card Name                                  2022 non-null   str
#  2   Expansion                                  2012 non-null   str
#  3   Collection No.                             2022 non-null   int64
#  4   Stage (Pokémon)/Type (Energy and Trainer)  2022 non-null   str
#  5   Rule                                       353 non-null    str
#  6   Category                                   392 non-null    str
#  7   Previous stage                             857 non-null    str
#  8   HP                                         1815 non-null   float64
#  9   Type                                       1825 non-null   str
#  10  Weakness                                   1734 non-null   str
#  11  Resistance (Type)                          376 non-null    str
#  12  Retreat                                    1748 non-null   float64
#  13  Move Name                                  1811 non-null   str
#  14  Cost                                       1556 non-null   str
#  15  Damage                                     1285 non-null   str
#  16  Effect Explanation                         1481 non-null   str
# dtypes: float64(2), int64(2), str(13)
# memory usage: 268.7 KB

# %%
df.head(50)
# Out:
#     Card ID                    Card Name Expansion  Collection No.  \
# 0         1             Basic {G} Energy       SVE               1
# 1         2             Basic {R} Energy       SVE               2
# 2         3             Basic {W} Energy       SVE               3
# 3         4             Basic {L} Energy       SVE               4
# 4         5             Basic {P} Energy       SVE               5
# 5         6             Basic {F} Energy       SVE               6
# 6         7             Basic {D} Energy       SVE               7
# 7         8             Basic {M} Energy       SVE               8
# 8         9             Boomerang Energy       TWM             166
# 9        10             Neo Upper Energy       TEF             162
# 10       11                  Mist Energy       TEF             161
# 11       12                Legacy Energy       TWM             167
# 12       13             Enriching Energy       SSP             191
# 13       14                 Spiky Energy       JTG             159
# 14       15         Team Rocket's Energy       DRI             182
# 15       16                 Prism Energy       BLK              86
# 16       17              Ignition Energy       WHT              86
# 17       18            Grow Grass Energy       POR              86
# 18       19      Telepath Psychic Energy       POR              87
# 19       20         Rock Fighting Energy       POR              88
# 20       21                      Scrafty     PROMO             188
# 21       21                      Scrafty     PROMO             188
# 22       22                   Hippopotas       DRI             105
# 23       23                    Hippowdon       DRI             106
# 24       23                    Hippowdon       DRI             106
# 25       24  Team Rocket's Kangaskhan ex       ASC             162
# 26       24  Team Rocket's Kangaskhan ex       ASC             162
# 27       25                       Pinsir       TWM               3
# 28       25                       Pinsir       TWM               3
# 29       26                      Leafeon       TWM              11
# 30       26                      Leafeon       TWM              11
# 31       27                  Iron Leaves       TWM              19
# 32       27                  Iron Leaves       TWM              19
# 33       28                 Poltchageist       TWM              20
# 34       28                 Poltchageist       TWM              20
# 35       29                 Sinistcha ex       TWM              23
# 36       29                 Sinistcha ex       TWM              23
# 37       30                  Magcargo ex       TWM              29
# 38       30                  Magcargo ex       TWM              29
# 39       30                  Magcargo ex       TWM              29
# 40       31                       Chi-Yu       TWM              39
# 41       31                       Chi-Yu       TWM              39
# 42       32                      Glaceon       TWM              54
# 43       32                      Glaceon       TWM              54
# 44       33                      Froakie       TWM              56
# 45       33                      Froakie       TWM              56
# 46       34                    Frogadier       TWM              57
# 47       35                 Walking Wake       TWM              63
# 48       35                 Walking Wake       TWM              63
# 49       36                      Morpeko       TWM              72
#
#    Stage (Pokémon)/Type (Energy and Trainer)        Rule  \
# 0                               Basic Energy         NaN
# 1                               Basic Energy         NaN
# 2                               Basic Energy         NaN
# 3                               Basic Energy         NaN
# 4                               Basic Energy         NaN
# 5                               Basic Energy         NaN
# 6                               Basic Energy         NaN
# 7                               Basic Energy         NaN
# 8                             Special Energy         NaN
# 9                             Special Energy    ACE SPEC
# 10                            Special Energy         NaN
# 11                            Special Energy    ACE SPEC
# 12                            Special Energy    ACE SPEC
# 13                            Special Energy         NaN
# 14                            Special Energy         NaN
# 15                            Special Energy         NaN
# 16                            Special Energy         NaN
# 17                            Special Energy         NaN
# 18                            Special Energy         NaN
# 19                            Special Energy         NaN
# 20                           Stage 1 Pokémon         NaN
# 21                           Stage 1 Pokémon         NaN
# 22                             Basic Pokémon         NaN
# 23                           Stage 1 Pokémon         NaN
# 24                           Stage 1 Pokémon         NaN
# 25                             Basic Pokémon  Pokémon ex
# 26                             Basic Pokémon  Pokémon ex
# 27                             Basic Pokémon         NaN
# 28                             Basic Pokémon         NaN
# 29                           Stage 1 Pokémon         NaN
# 30                           Stage 1 Pokémon         NaN
# 31                             Basic Pokémon         NaN
# 32                             Basic Pokémon         NaN
# 33                             Basic Pokémon         NaN
# 34                             Basic Pokémon         NaN
# 35                           Stage 1 Pokémon  Pokémon ex
# 36                           Stage 1 Pokémon  Pokémon ex
# 37                           Stage 1 Pokémon  Pokémon ex
# 38                           Stage 1 Pokémon  Pokémon ex
# 39                           Stage 1 Pokémon  Pokémon ex
# 40                             Basic Pokémon         NaN
# 41                             Basic Pokémon         NaN
# 42                           Stage 1 Pokémon         NaN
# 43                           Stage 1 Pokémon         NaN
# 44                             Basic Pokémon         NaN
# 45                             Basic Pokémon         NaN
# 46                           Stage 1 Pokémon         NaN
# 47                             Basic Pokémon         NaN
# 48                             Basic Pokémon         NaN
# 49                             Basic Pokémon         NaN
#
#                           Category Previous stage     HP  \
# 0                              NaN            NaN    NaN
# 1                              NaN            NaN    NaN
# 2                              NaN            NaN    NaN
# 3                              NaN            NaN    NaN
# 4                              NaN            NaN    NaN
# 5                              NaN            NaN    NaN
# 6                              NaN            NaN    NaN
# 7                              NaN            NaN    NaN
# 8                              NaN            NaN    NaN
# 9                              NaN            NaN    NaN
# 10                             NaN            NaN    NaN
# 11                             NaN            NaN    NaN
# 12                             NaN            NaN    NaN
# 13                             NaN            NaN    NaN
# 14                             NaN            NaN    NaN
# 15                             NaN            NaN    NaN
# 16                             NaN            NaN    NaN
# 17                             NaN            NaN    NaN
# 18                             NaN            NaN    NaN
# 19                             NaN            NaN    NaN
# 20                             NaN        Scraggy  120.0
# 21                             NaN        Scraggy  120.0
# 22                             NaN            NaN   90.0
# 23                             NaN     Hippopotas  160.0
# 24                             NaN     Hippopotas  160.0
# 25  Trainer's Pokémon（Team Rocket）            NaN  230.0
# 26  Trainer's Pokémon（Team Rocket）            NaN  230.0
# 27                             NaN            NaN  110.0
# 28                             NaN            NaN  110.0
# 29                             NaN          Eevee  120.0
# 30                             NaN          Eevee  120.0
# 31                          Future            NaN  120.0
# 32                          Future            NaN  120.0
# 33                             NaN            NaN   30.0
# 34                             NaN            NaN   30.0
# 35                             NaN   Poltchageist  240.0
# 36                             NaN   Poltchageist  240.0
# 37                      Tera(Fire)         Slugma  270.0
# 38                      Tera(Fire)         Slugma  270.0
# 39                      Tera(Fire)         Slugma  270.0
# 40                             NaN            NaN  110.0
# 41                             NaN            NaN  110.0
# 42                             NaN          Eevee  120.0
# 43                             NaN          Eevee  120.0
# 44                             NaN            NaN   60.0
# 45                             NaN            NaN   60.0
# 46                             NaN        Froakie   90.0
# 47                         Ancient            NaN  130.0
# 48                         Ancient            NaN  130.0
# 49                             NaN            NaN   70.0
#
#                           Type Weakness Resistance (Type)  Retreat  \
# 0                          {G}      NaN               NaN      NaN
# 1                          {R}      NaN               NaN      NaN
# 2                          {W}      NaN               NaN      NaN
# 3                          {L}      NaN               NaN      NaN
# 4                          {P}      NaN               NaN      NaN
# 5                          {F}      NaN               NaN      NaN
# 6                          {D}      NaN               NaN      NaN
# 7                          {M}      NaN               NaN      NaN
# 8                          {C}      NaN               NaN      NaN
# 9                       {A}{A}      NaN               NaN      NaN
# 10                         {C}      NaN               NaN      NaN
# 11                         {A}      NaN               NaN      NaN
# 12                         {C}      NaN               NaN      NaN
# 13                         {C}      NaN               NaN      NaN
# 14  {Team Rocket}{Team Rocket}      NaN               NaN      NaN
# 15                         {A}      NaN               NaN      NaN
# 16                   {C}{C}{C}      NaN               NaN      NaN
# 17                         {G}      NaN               NaN      NaN
# 18                         {P}      NaN               NaN      NaN
# 19                         {F}      NaN               NaN      NaN
# 20                         {D}      {G}               NaN      1.0
# 21                         {D}      {G}               NaN      1.0
# 22                         {F}      {G}               NaN      3.0
# 23                         {F}      {G}               NaN      4.0
# 24                         {F}      {G}               NaN      4.0
# 25                         {C}      {F}               NaN      2.0
# 26                         {C}      {F}               NaN      2.0
# 27                         {G}      {R}               NaN      2.0
# 28                         {G}      {R}               NaN      2.0
# 29                         {G}      {R}               NaN      1.0
# 30                         {G}      {R}               NaN      1.0
# 31                         {G}      {R}               NaN      1.0
# 32                         {G}      {R}               NaN      1.0
# 33                         {G}      {R}               NaN      1.0
# 34                         {G}      {R}               NaN      1.0
# 35                         {G}      {R}               NaN      1.0
# 36                         {G}      {R}               NaN      1.0
# 37                         {R}      {W}               NaN      3.0
# 38                         {R}      {W}               NaN      3.0
# 39                         {R}      {W}               NaN      3.0
# 40                         {R}      {W}               NaN      1.0
# 41                         {R}      {W}               NaN      1.0
# 42                         {W}      {M}               NaN      1.0
# 43                         {W}      {M}               NaN      1.0
# 44                         {W}      {L}               NaN      1.0
# 45                         {W}      {L}               NaN      1.0
# 46                         {W}      {L}               NaN      1.0
# 47                         {W}      {L}               NaN      1.0
# 48                         {W}      {L}               NaN      1.0
# 49                         {L}      {F}               NaN      1.0
#
#                         Move Name     Cost Damage  \
# 0                             NaN      NaN    NaN
# 1                             NaN      NaN    NaN
# 2                             NaN      NaN    NaN
# 3                             NaN      NaN    NaN
# 4                             NaN      NaN    NaN
# 5                             NaN      NaN    NaN
# 6                             NaN      NaN    NaN
# 7                             NaN      NaN    NaN
# 8                             NaN      NaN    NaN
# 9                             NaN      NaN    NaN
# 10                            NaN      NaN    NaN
# 11                            NaN      NaN    NaN
# 12                            NaN      NaN    NaN
# 13                            NaN      NaN    NaN
# 14                            NaN      NaN    NaN
# 15                            NaN      NaN    NaN
# 16                            NaN      NaN    NaN
# 17                            NaN      NaN    NaN
# 18                            NaN      NaN    NaN
# 19                            NaN      NaN    NaN
# 20                   Nab ’n’ Dash        ●    NaN
# 21                 High Jump Kick    {D}●●    100
# 22                      Push Down      {F}     10
# 23                            Ram   {F}{F}     60
# 24                Super Sandstorm  {F}{F}●    150
# 25                    Comet Punch       ●●    30×
# 26                  Wicked Impact      ●●●    120
# 27                    Slow Crunch     {G}●    NaN
# 28             Superpowered Horns    {G}●●    100
# 29              Leaflet Blessings        ●    NaN
# 30                     Solar Beam     {G}●     70
# 31                   Recovery Net      {G}    NaN
# 32                  Avenging Edge    {G}●●    100
# 33  [Ability] Storehouse Hideaway      NaN    NaN
# 34                           Hook      {G}     10
# 35                        Re-Brew        ●    NaN
# 36                  Matcha Splash     {G}●    120
# 37                         [Tera]      NaN    NaN
# 38                      Hot Magma     {R}●     70
# 39                    Ground Burn  {R}{R}●    140
# 40                         Allure        ●    NaN
# 41                  Ground Melter     {R}●     60
# 42               Permeating Chill      {W}     30
# 43                 Icicle Missile     {W}●     70
# 44                          Flock      {W}    NaN
# 45                           Flop      {W}     10
# 46                  Numbing Water      {W}     20
# 47                    Aurora Gain      {W}     20
# 48               Undulating Slice  {W}{W}●    20×
# 49           [Ability] Snack Seek      NaN    NaN
#
#                                    Effect Explanation
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   As long as this card is attached to a Pokémon,...
# 9   As long as this card is attached to a Pokémon,...
# 10  As long as this card is attached to a Pokémon,...
# 11  As long as this card is attached to a Pokémon,...
# 12  As long as this card is attached to a Pokémon,...
# 13  As long as this card is attached to a Pokémon,...
# 14  This card can only be attached to a Team Rocke...
# 15  As long as this card is attached to a Pokémon,...
# 16  If this card is attached to 1 of your Pokémon,...
# 17  As long as this card is attached to a Pokémon,...
# 18  As long as this card is attached to a Pokémon,...
# 19  As long as this card is attached to a Pokémon,...
# 20  Search your deck for a number of cards up to t...
# 21                                                NaN
# 22  Switch out your opponent’s Active Pokémon to t...
# 23                                                NaN
# 24  This attack also does 40 damage to each Benche...
# 25  Flip 4 coins. This attack does 30 damage for e...
# 26  If you played a Supporter card that has “Team ...
# 27  Discard all Energy from this Pokémon. At the e...
# 28                                                NaN
# 29  Attach a Basic {G} Energy card from your hand ...
# 30                                                NaN
# 31  Put up to 2 Pokémon from your discard pile int...
# 32  If any of your Pokémon were Knocked Out by dam...
# 33  As long as this Pokémon is on your Bench, prev...
# 34                                                NaN
# 35  Put 2 damage counters on 1 of your opponent’s ...
# 36          Heal 30 damage from each of your Pokémon.
# 37  As long as this Pokémon is on your Bench, prev...
# 38      Your opponent’s Active Pokémon is now Burned.
# 39  Discard the top card of each player’s deck. Th...
# 40                                      Draw 2 cards.
# 41  If a Stadium is in play, this attack does 60 m...
# 42  At the end of your opponent’s next turn, put 9...
# 43                                                NaN
# 44  Search your deck for up to 2 Froakie and put t...
# 45                                                NaN
# 46  Flip a coin. If heads, your opponent’s Active ...
# 47                  Heal 20 damage from this Pokémon.
# 48  Put up to 9 damage counters on this Pokémon. T...
# 49  Once during your turn, you may look at the top...

# %%
pokemon_id = 35

all_attack_costs = df.loc[df['Card ID'] == pokemon_id, 'Cost']

int_costs = []

for cost_string in all_attack_costs:
    if pd.isna(cost_string):
        int_costs.append(0)
    else:
        total_energy = cost_string.count('{') + cost_string.count('●')
        int_costs.append(total_energy)

biggest_attack_cost = max(int_costs)

print(all_attack_costs)
biggest_attack_cost
# Out:
# 47        {W}
# 48    {W}{W}●
# Name: Cost, dtype: str
# 3
